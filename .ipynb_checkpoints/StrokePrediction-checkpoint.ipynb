# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyp
import seaborn as sns

# %%
ds= pd.read_csv('healthcare-dataset-stroke-data.csv')
ds.head(7) #test to check if file is readable
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
# 5  56669    Male  81.0             0              0          Yes
# 6  53882    Male  74.0             1              1          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
# ...

# %%
#check how many empty values are there
ds.isna().sum() #it is not neccessary to do delete or fill in the NaN values
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
ds = ds[ds['bmi'].notna()]

# %%
#look at the data types to see which columns need to be encoded
ds.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
ds = ds[ds['smoking_status'] != 'Unknown']

# %%
ds = ds[ds['gender'] != 'Other']
ds = ds.reset_index(drop = True)

# %%
#visualize count
sns.countplot(x=ds['stroke'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='count'>

# %%
#encode categorical data values
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer

labelencoder_Y = LabelEncoder()
ds.iloc[:,1] = labelencoder_Y.fit_transform(ds.iloc[:,1].values)
ds.iloc[:,5] = labelencoder_Y.fit_transform(ds.iloc[:,5].values)
ds.iloc[:,7] = labelencoder_Y.fit_transform(ds.iloc[:,7].values)

one_hot = LabelBinarizer()
x = one_hot.fit_transform(ds.iloc[:,6])
ds = ds.join(pd.DataFrame(data = x, columns = one_hot.classes_))

x = one_hot.fit_transform(ds.iloc[:,10])
ds = ds.join(pd.DataFrame(data = x, columns = one_hot.classes_))
ds.head(7)
# Out:
#       id  gender   age  hypertension  heart_disease  ever_married  \
# 0   9046       1  67.0             0              1             1
# 1  31112       1  80.0             0              1             1
# 2  60182       0  49.0             0              0             1
# 3   1665       0  79.0             1              0             1
# 4  56669       1  81.0             0              0             1
# 5  53882       1  74.0             1              1             1
# 6  10434       0  69.0             0              0             0
#
#        work_type  Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private               1             228.69  36.6  formerly smoked
# 1        Private               0             105.92  32.5     never smoked
# 2        Private               1             171.23  34.4           smokes
# 3  Self-employed               0             174.12  24.0     never smoked
# ...

# %%
drop_list=['work_type', 'smoking_status']
ds = ds.drop(drop_list, axis=1)
ds.head(7)
# Out:
#       id  gender   age  hypertension  heart_disease  ever_married  \
# 0   9046       1  67.0             0              1             1
# 1  31112       1  80.0             0              1             1
# 2  60182       0  49.0             0              0             1
# 3   1665       0  79.0             1              0             1
# 4  56669       1  81.0             0              0             1
# 5  53882       1  74.0             1              1             1
# 6  10434       0  69.0             0              0             0
#
#    Residence_type  avg_glucose_level   bmi  stroke  Govt_job  Never_worked  \
# 0               1             228.69  36.6       1         0             0
# 1               0             105.92  32.5       1         0             0
# 2               1             171.23  34.4       1         0             0
# 3               0             174.12  24.0       1         0             0
# ...

# %%
ds.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# stroke               0
# Govt_job             0
# Never_worked         0
# Private              0
# Self-employed        0
# children             0
# formerly smoked      0
# never smoked         0
# smokes               0
# dtype: int64

# %%
#Balance the classes
from sklearn.utils import resample
import random
class0 = ds[ds.stroke == 1]
class1 = ds[ds.stroke == 0]

n_class0 = len(class0)
class1_downsampled = resample(class1, replace=True, n_samples=n_class0, random_state=0)
ds = pd.concat([class0, class1_downsampled])

#visualize count
sns.countplot(x=ds['stroke'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='count'>

# %%
ds.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# stroke               0
# Govt_job             0
# Never_worked         0
# Private              0
# Self-employed        0
# children             0
# formerly smoked      0
# never smoked         0
# smokes               0
# dtype: int64

# %%
#visualize correlation
pyp.figure(figsize=(10,10))
sns.heatmap(ds.iloc[:,1:18].corr(), annot=True, fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
#scale data to bring all features to the same magnitude(Feature scaling)
from sklearn.preprocessing import StandardScaler

output_data = ds.iloc[:,9]
ds = ds.drop('stroke', axis = 1)

sc = StandardScaler()
input_data = sc.fit_transform(ds.iloc[:,1:17])
print(round(input_data[:,0].mean()))
print(round(input_data[:,0].std()))
# Out:
# 0
# 1

# %%
def FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes):
    layers = []
    
    nodes_increment = (last_layer_nodes - first_layer_nodes)/ (n_layers-1)
    nodes = first_layer_nodes
    for i in range(1, n_layers+1):
        layers.append(math.ceil(nodes))
        nodes = nodes + nodes_increment
    
    return layers

# %%
from keras.models import Sequential
from keras.layers import Dense
def createmodel(n_layers, first_layer_nodes, last_layer_nodes, activation_func, loss_func):
    model = Sequential()
    n_nodes = FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes)
    for i in range(1, n_layers):
        if i==1:
            model.add(Dense(first_layer_nodes, input_dim=input_data.shape[1], activation=activation_func))
        else:
            model.add(Dense(n_nodes[i-1], activation=activation_func))
            
    #Finally, the output layer should have a single node in binary classification
    model.add(Dense(1, activation=activation_func))
    model.compile(optimizer='adam', loss=loss_func, metrics = ["accuracy"]) #note: metrics could also be 'mse'
    
    return model

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import math

model =  KerasClassifier(build_fn=createmodel, verbose = False)

# %%
from sklearn.model_selection import GridSearchCV

activation_funcs = ['sigmoid', 'relu', 'tanh'] 
loss_funcs = ['binary_crossentropy','hinge']
param_grid = dict(n_layers=[2,3], first_layer_nodes = [128,64,32], 
                  last_layer_nodes = [4],  activation_func = activation_funcs, 
                  loss_func = loss_funcs, batch_size = [100], epochs = [20,60])
grid = GridSearchCV(estimator = model, param_grid = param_grid)

# %%
grid.fit(input_data,output_data)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x0000025AE37D7A68> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.7055555701255798
# {'activation_func': 'tanh', 'batch_size': 100, 'epochs': 60, 'first_layer_nodes': 128, 'last_layer_nodes': 4, 'loss_func': 'hinge', 'n_layers': 3}

# %%
FindLayerNodesLinear(3, 128, 4)
# Out:
# [128, 66, 4]

# %%
#split data into training(80%) and test(20%)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(input_data, output_data, test_size = 0.20, random_state = 0)

# %%
from keras import callbacks 

def getModel():
    # define the keras model
    model = Sequential()
    model.add(Dense(128, input_dim=16, activation='tanh'))
    model.add(Dense(128, activation='tanh'))
    model.add(Dense(66, activation='tanh'))
    model.add(Dense(4, activation='tanh'))
    model.add(Dense(1, activation='sigmoid'))

    model.compile(loss='hinge', optimizer='adam', metrics=['accuracy'])
    return model

model = getModel()
earlystopping = callbacks.EarlyStopping(monitor ="accuracy", patience = 5, min_delta=0.0001) 

# fit the keras model on the dataset
model.fit(X_train, Y_train, epochs=2000, verbose = 1, batch_size=100, callbacks =[earlystopping])

# evaluate the keras model
_, accuracy_train = model.evaluate(X_train, Y_train)
_, accuracy_test = model.evaluate(X_test, Y_test)

print('Accuracy train: %.2f' % (accuracy_train*100))
print('Accuracy test: %.2f' % (accuracy_test*100))
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9771 - accuracy: 0.5796
# Epoch 2/2000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.8718 - accuracy: 0.6885
# Epoch 3/2000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8419 - accuracy: 0.7388
# Epoch 4/2000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8250 - accuracy: 0.7517
# Epoch 5/2000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7927 - accuracy: 0.7562
# Epoch 6/2000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8032 - accuracy: 0.7410
# Epoch 7/2000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7868 - accuracy: 0.7647
# Epoch 8/2000
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7918 - accuracy: 0.7694
# Epoch 9/2000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7726 - accuracy: 0.7861
# Epoch 10/2000
# ...

# %%
# predict crisp classes for test set
y_classes = model.predict(X_test, verbose = 0)
y_classes = (y_classes > 0.5).astype('int32')
# reduce to 1d array
y_classes = y_classes[:, 0]

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(Y_test, y_classes)
print('Accuracy: %f' % accuracy)
# precision tp / (tp + fp)
precision = precision_score(Y_test, y_classes)
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(Y_test, y_classes)
print('Recall: %f' % recall)
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(Y_test, y_classes)
print('F1 score: %f' % f1)
# Out:
# Accuracy: 0.736111
# Precision: 0.738095
# Recall: 0.794872
# F1 score: 0.765432

# %%
#improving accuracy with cross validation
from sklearn.model_selection import cross_val_score, KFold
kf = KFold(n_splits=10, shuffle=True, random_state=0)
model_keras =  KerasClassifier(build_fn = getModel, epochs = 60, batch_size = 100, verbose = False)  
cv = cross_val_score(model_keras, input_data, output_data, cv=kf, scoring = 'accuracy', n_jobs = -1)
print(cv.mean())
print()
# Out:
# 0.7555555555555555
